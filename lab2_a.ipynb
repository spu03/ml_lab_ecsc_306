# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
rng = numpy.random

# %%
learning_rate = 0.005
training_epochs = 100
display_step = 50

# %%
train_X = numpy.asarray([1,2,4,3,5])
train_Y = numpy.asarray([1,3,3,2,5])
n_samples = train_X.shape[0]

# %%
X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
W = tf.Variable(rng.randn(), name="weight")
b = tf.Variable(rng.randn(), name="bias")

# %%
# Construct a linear model
pred = tf.add(tf.multiply(X, W), b)

# %%
# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "W=", sess.run(W), "b=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "W=", sess.run(W), "b=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(W) * train_X + sess.run(b), label='Fitted line')
    plt.legend()
    plt.show()
# Out:
# Epoch: 0050 cost= 0.335277587 W= 0.539358 b= 0.948076
# Epoch: 0100 cost= 0.267806232 W= 0.643707 b= 0.951083
# Optimization Finished!
# Training cost= 0.267806 W= 0.643707 b= 0.951083

# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
rng = numpy.random

learning_rate = 0.0005
training_epochs = 500
display_step = 50

train_X = numpy.asarray([1,2,4,3,5])
train_Y = numpy.asarray([1,3,3,2,5])
n_samples = train_X.shape[0]

X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
t_0 = tf.Variable(rng.randn(), name="weight")
t_1 = tf.Variable(rng.randn(), name="bias")


# Construct a linear model
pred = tf.add(tf.multiply(X, t_0), t_1)

# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
# Out:
# Epoch: 0050 cost= 16.778505325 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 9.388325691 t_0= -1.40144 t_1= 0.435761
# Epoch: 0150 cost= 5.300386906 t_0= -1.40144 t_1= 0.435761
# Epoch: 0200 cost= 3.039128065 t_0= -1.40144 t_1= 0.435761
# Epoch: 0250 cost= 1.788314819 t_0= -1.40144 t_1= 0.435761
# Epoch: 0300 cost= 1.096436262 t_0= -1.40144 t_1= 0.435761
# Epoch: 0350 cost= 0.713735342 t_0= -1.40144 t_1= 0.435761
# Epoch: 0400 cost= 0.502054989 t_0= -1.40144 t_1= 0.435761
# Epoch: 0450 cost= 0.384972572 t_0= -1.40144 t_1= 0.435761
# Epoch: 0500 cost= 0.320216477 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 0.320216 t_0= -1.40144 t_1= 0.435761

# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
rng = numpy.random

learning_rate = 0.005
training_epochs1 = 100
training_epochs2 = 500
training_epochs3 = 1000
display_step = 50

train_X = numpy.asarray([1,2,3,4,5])
train_Y = numpy.asarray([6,7,8,9,10])
n_samples = train_X.shape[0]

X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
t_0 = tf.Variable(rng.randn(), name="weight")
t_1 = tf.Variable(rng.randn(), name="bias")


# Construct a linear model
pred = tf.add(tf.multiply(X, t_0), t_1)

# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs1):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
    
    # Fit all training data
    for epoch in range(training_epochs2):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
    
    # Fit all training data
    for epoch in range(training_epochs3):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
# Out:
# Epoch: 0050 cost= 0.731555104 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 0.556934595 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 0.556935 t_0= -1.40144 t_1= 0.435761
# Epoch: 0050 cost= 0.511011422 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 0.469436556 t_0= -1.40144 t_1= 0.435761
# Epoch: 0150 cost= 0.431259632 t_0= -1.40144 t_1= 0.435761
# Epoch: 0200 cost= 0.396188140 t_0= -1.40144 t_1= 0.435761
# Epoch: 0250 cost= 0.363968700 t_0= -1.40144 t_1= 0.435761
# Epoch: 0300 cost= 0.334370524 t_0= -1.40144 t_1= 0.435761
# Epoch: 0350 cost= 0.307178348 t_0= -1.40144 t_1= 0.435761
# Epoch: 0400 cost= 0.282197654 t_0= -1.40144 t_1= 0.435761
# Epoch: 0450 cost= 0.259248644 t_0= -1.40144 t_1= 0.435761
# Epoch: 0500 cost= 0.238166526 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 0.238167 t_0= -1.40144 t_1= 0.435761
# Epoch: 0050 cost= 0.218798563 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 0.201005384 t_0= -1.40144 t_1= 0.435761
# ...

# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
rng = numpy.random

learning_rate = 0.0005
training_epochs1 = 100
training_epochs2 = 500
training_epochs3 = 1000
display_step = 50

train_X = numpy.asarray([1,2,3,4,5])
train_Y = numpy.asarray([6,7,8,9,10])
n_samples = train_X.shape[0]

X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
t_0 = tf.Variable(rng.randn(), name="weight")
t_1 = tf.Variable(rng.randn(), name="bias")


# Construct a linear model
pred = tf.add(tf.multiply(X, t_0), t_1)

# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs1):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
    
    # Fit all training data
    for epoch in range(training_epochs2):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
    
    # Fit all training data
    for epoch in range(training_epochs3):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
# Out:
# Epoch: 0050 cost= 4.294432640 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 3.354733229 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 3.35473 t_0= -1.40144 t_1= 0.435761
# Epoch: 0050 cost= 2.826363325 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 2.525673866 t_0= -1.40144 t_1= 0.435761
# Epoch: 0150 cost= 2.351063251 t_0= -1.40144 t_1= 0.435761
# Epoch: 0200 cost= 2.246312380 t_0= -1.40144 t_1= 0.435761
# Epoch: 0250 cost= 2.180307150 t_0= -1.40144 t_1= 0.435761
# Epoch: 0300 cost= 2.135828495 t_0= -1.40144 t_1= 0.435761
# Epoch: 0350 cost= 2.103345156 t_0= -1.40144 t_1= 0.435761
# Epoch: 0400 cost= 2.077575207 t_0= -1.40144 t_1= 0.435761
# Epoch: 0450 cost= 2.055594683 t_0= -1.40144 t_1= 0.435761
# Epoch: 0500 cost= 2.035783291 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 2.03578 t_0= -1.40144 t_1= 0.435761
# Epoch: 0050 cost= 2.017241955 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 1.999470711 t_0= -1.40144 t_1= 0.435761
# ...

# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
rng = numpy.random

learning_rate = 0.5
training_epochs1 = 100
training_epochs2 = 500
training_epochs3 = 1000
display_step = 50

train_X = numpy.asarray([1,2,3,4,5])
train_Y = numpy.asarray([6,7,8,9,10])
n_samples = train_X.shape[0]

X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
t_0 = tf.Variable(rng.randn(), name="weight")
t_1 = tf.Variable(rng.randn(), name="bias")


# Construct a linear model
pred = tf.add(tf.multiply(X, t_0), t_1)

# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs1):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
    
    # Fit all training data
    for epoch in range(training_epochs2):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
    
    # Fit all training data
    for epoch in range(training_epochs3):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
# Out:
# Epoch: 0050 cost= 0.000819302 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 0.000000766 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 7.65728e-07 t_0= -1.40144 t_1= 0.435761
# Epoch: 0050 cost= 0.000000001 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Epoch: 0150 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Epoch: 0200 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Epoch: 0250 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Epoch: 0300 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Epoch: 0350 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Epoch: 0400 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Epoch: 0450 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Epoch: 0500 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 8.41283e-13 t_0= -1.40144 t_1= 0.435761
# Epoch: 0050 cost= 0.000000000 t_0= -1.40144 t_1= 0.435761
# ...

# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
rng = numpy.random

learning_rate = 0.05
training_epochs1 = 100
training_epochs2 = 500
training_epochs3 = 1000
display_step = 50

train_X = numpy.asarray([1,2,3,4,5])
train_Y = numpy.asarray([6,7,8,9,10])
n_samples = train_X.shape[0]

X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
t_0 = tf.Variable(rng.randn(), name="weight")
t_1 = tf.Variable(rng.randn(), name="bias")


# Construct a linear model
pred = tf.add(tf.multiply(X, t_0), t_1)

# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs1):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
    
    # Fit all training data
    for epoch in range(training_epochs2):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
    
    # Fit all training data
    for epoch in range(training_epochs3):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "t_0=", sess.run(W), "t_1=", sess.run(b))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "t_0=", sess.run(W), "t_1=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(t_0) * train_X + sess.run(t_1), label='Fitted line')
    plt.legend()
    plt.show()
# Out:
# Epoch: 0050 cost= 1.119962573 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 0.467060626 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 0.467061 t_0= -1.40144 t_1= 0.435761
# Epoch: 0050 cost= 0.194779828 t_0= -1.40144 t_1= 0.435761
# Epoch: 0100 cost= 0.081229597 t_0= -1.40144 t_1= 0.435761
# Epoch: 0150 cost= 0.033875238 t_0= -1.40144 t_1= 0.435761
# Epoch: 0200 cost= 0.014127064 t_0= -1.40144 t_1= 0.435761
# Epoch: 0250 cost= 0.005891237 t_0= -1.40144 t_1= 0.435761
# Epoch: 0300 cost= 0.002456816 t_0= -1.40144 t_1= 0.435761
# Epoch: 0350 cost= 0.001024618 t_0= -1.40144 t_1= 0.435761
# Epoch: 0400 cost= 0.000427302 t_0= -1.40144 t_1= 0.435761
# Epoch: 0450 cost= 0.000178196 t_0= -1.40144 t_1= 0.435761
# Epoch: 0500 cost= 0.000074325 t_0= -1.40144 t_1= 0.435761
# Optimization Finished!
# Training cost= 7.43245e-05 t_0= -1.40144 t_1= 0.435761
# Epoch: 0050 cost= 0.000031003 t_0= -1.40144 t_1= 0.435761
# ...
